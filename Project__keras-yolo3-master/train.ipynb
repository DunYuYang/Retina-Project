# %% [markdown]
# # YOLOv3 Training

# %% [markdown]
# # Package
# - numpy = 1.15.2
# - opencv-python =3.4.3
# - tqdm = 4.27.0
# - matplotlib = 2.2.3
# - tensorflow = 1.10.0
# - keras = 2.2.2

# %% [markdown]
# # 架構流程
# - 1. 動所需參數train_annot_folde,train_image_folder,cache_name,labels,saved_weights_name
# - 2. 執行訓練

# %%
#! /usr/bin/env python
# https://github.com/experiencor/keras-yolo3
import argparse
import os
import numpy as np
import json
from voc import parse_voc_annotation
from yolo import create_yolov3_model, dummy_loss
from generator import BatchGenerator
from utils.utils import normalize, evaluate, makedirs
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
from callbacks import CustomModelCheckpoint, CustomTensorBoard
from utils.multi_gpu_model import multi_gpu_model
import tensorflow as tf
import keras
from keras.models import load_model
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def create_training_instances(
    train_annot_folder,
    train_image_folder,
    train_cache,
    valid_annot_folder,
    valid_image_folder,
    valid_cache,
    labels,
):
    # parse annotations of the training set
    train_ints, train_labels = parse_voc_annotation(train_annot_folder, train_image_folder, train_cache, labels)
    # parse annotations of the validation set, if any, otherwise split the training set
    if os.path.exists(valid_annot_folder):
        valid_ints, valid_labels = parse_voc_annotation(valid_annot_folder, valid_image_folder, valid_cache, labels)
    else:
        print("valid_annot_folder not exists. Spliting the trainining set.")

        train_valid_split = int(0.8*len(train_ints))
        np.random.seed(0)
        np.random.shuffle(train_ints)
        np.random.seed()

        valid_ints = train_ints[train_valid_split:]
        train_ints = train_ints[:train_valid_split]

    # compare the seen labels with the given labels
    if len(labels) > 0:
        overlap_labels = set(labels).intersection(set(train_labels.keys()))

        print('Seen labels: \t'  + str(train_labels) + '\n')
        print('Given labels: \t' + str(labels))

        # return None, None, None if some given label is not in the dataset
        if len(overlap_labels) < len(labels):
            print('Some labels have no annotations! Please revise the list of labels')
            return None, None, None
    else:
        print('No labels are provided. Train on all seen labels.')
        print(train_labels)
        labels = train_labels.keys()

    max_box_per_image = max([len(inst['object']) for inst in (train_ints + valid_ints)])

    return train_ints, valid_ints, sorted(labels), max_box_per_image

# %%
def create_callbacks(saved_weights_name, model_to_save):
    
    early_stop = EarlyStopping(
        monitor     = 'loss', 
        min_delta   = 0.01, 
        patience    = 5, 
        mode        = 'min', 
        verbose     = 1
    )
    checkpoint = CustomModelCheckpoint(
        model_to_save   = model_to_save,
        filepath        = saved_weights_name,# + '{epoch:02d}.h5', 
        monitor         = 'loss', 
        verbose         = 1, 
        save_best_only  = True, 
        mode            = 'min', 
        period          = 1
    )
    reduce_on_plateau = ReduceLROnPlateau(
        monitor  = 'loss',
        factor   = 0.1,
        patience = 2,
        verbose  = 1,
        mode     = 'min',
        epsilon  = 0.01,
        cooldown = 0,
        min_lr   = 0
    )    
    return [early_stop, checkpoint, reduce_on_plateau]

# %%
def create_model(
    nb_class, 
    anchors, 
    max_box_per_image, 
    max_grid, batch_size, 
    warmup_batches, 
    ignore_thresh,  
    saved_weights_name, 
    lr,
    grid_scales,
    obj_scale=5,
    noobj_scale=1,
    xywh_scale=1,
    class_scale=1  
):
    train_model, infer_model = create_yolov3_model(
        nb_class            = nb_class, 
        anchors             = anchors, 
        max_box_per_image   = max_box_per_image, 
        max_grid            = max_grid, 
        batch_size          = batch_size, 
        warmup_batches      = warmup_batches,
        ignore_thresh       = ignore_thresh,
        grid_scales         = grid_scales,
        obj_scale           = obj_scale,
        noobj_scale         = noobj_scale,
        xywh_scale          = xywh_scale,
        class_scale         = class_scale
    )  

    # load the pretrained weight if exists, otherwise load the backend weight only
    if os.path.exists(saved_weights_name): 
        print("\nLoading pretrained weights.\n")
        train_model.load_weights(saved_weights_name)
    else:
        train_model.load_weights("backend.h5", by_name=True)          

    optimizer = Adam(lr=lr, clipnorm=0.001)
    train_model.compile(loss=dummy_loss, optimizer=optimizer)             

    return train_model, infer_model

# %% [markdown]
# # 參數設置

# %%
#更改訓練資料夾路徑，以及cache_name
# Parse the annotations

min_input_size = 288
max_input_size = 448
# Create the generators 
anchors = [55,69, 75,234, 133,240, 136,129, 142,363, 203,290, 228,184, 285,359, 341,260]
labels = ['CNV', 'DME', 'DRUSEN']

# 可在這更改batch_size
batch_size = 2

train_annot_folder = './retina/annots/'
train_image_folder = './retina/images/'
cache_name = 'retina.pkl'

#更改儲存model名稱
# Create the model 
saved_weights_name = 'retina.h5'

warmup_epochs = 3
nb_epochs = 30
train_times = 8
ignore_thresh = 0.5
learning_rate = 1e-4
grid_scales = [1,1,1]
obj_scale = 5

valid_annot_folder = ''
valid_image_folder = ''
valid_cache_name = ''

# %%
train_ints, valid_ints, labels, max_box_per_image = create_training_instances(
    train_annot_folder,
    train_image_folder,
    cache_name,
    valid_annot_folder,
    valid_image_folder,
    valid_cache_name,
    labels
)
print('\nTraining on: \t' + str(labels) + '\n')


train_generator = BatchGenerator(
    instances           = train_ints, 
    anchors             = anchors,   
    labels              = labels,        
    downsample          = 32, # ratio between network input's size and network output's size, 32 for YOLOv3
    max_box_per_image   = max_box_per_image,
    batch_size          = batch_size,
    min_net_size        = min_input_size,
    max_net_size        = max_input_size,   
    shuffle             = True, 
    jitter              = 0.3, 
    norm                = normalize
)

valid_generator = BatchGenerator(
    instances           = valid_ints, 
    anchors             = anchors,   
    labels              = labels,        
    downsample          = 32, # ratio between network input's size and network output's size, 32 for YOLOv3
    max_box_per_image   = max_box_per_image,
    batch_size          = batch_size,
    min_net_size        = min_input_size,
    max_net_size        = max_input_size,   
    shuffle             = True, 
    jitter              = 0.0, 
    norm                = normalize
)


if os.path.exists(saved_weights_name): 
    warmup_epochs = 0
warmup_batches = warmup_epochs * (train_times*len(train_generator))

train_model, infer_model = create_model(
    nb_class            = len(labels), 
    anchors             = anchors, 
    max_box_per_image   = max_box_per_image, 
    max_grid            = [max_input_size, max_input_size], 
    batch_size          = batch_size, 
    warmup_batches      = warmup_batches,
    ignore_thresh       = 0.5,
    saved_weights_name  = saved_weights_name,
    lr                  = 1e-4,
    grid_scales         = [1,1,1],

)

# Start training
callbacks = create_callbacks(saved_weights_name, infer_model)

train_model.fit_generator(
    generator        = train_generator, 
    steps_per_epoch  = len(train_generator) * train_times, 
    epochs           = nb_epochs + warmup_epochs, 
    verbose          = 2,
    callbacks        = callbacks, 
    workers          = 4,
    max_queue_size   = 8
)
# Out:
# valid_annot_folder not exists. Spliting the trainining set.
# Seen labels: 	{'CNV': 252, 'DME': 146, 'DRUSEN': 183}
#
# Given labels: 	['CNV', 'DME', 'DRUSEN']
#
# Training on: 	['CNV', 'DME', 'DRUSEN']
#
# WARNING:tensorflow:From /home/jovyan/Project__keras-yolo3-master/yolo.py:24: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/jovyan/Project__keras-yolo3-master/yolo.py:149: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/jovyan/Project__keras-yolo3-master/yolo.py:179: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
# ```python
#     sess = tf.compat.v1.Session()
#     with sess.as_default():
#         tensor = tf.range(10)
#         print_op = tf.print(tensor)
#         with tf.control_dependencies([print_op]):
#           out = tf.add(tensor, tensor)
#         sess.run(out)
#     ```
# Additionally, to use tf.print in python 2.7, users must make sure to import
# the following:
#
#   `from __future__ import print_function`
#
#
# Loading pretrained weights.
# /opt/conda/lib/python3.7/site-packages/keras/callbacks/callbacks.py:998: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Epoch 1/30
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing: resizing:  352 352
#  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
#  - 193s - loss: 3.8217 - yolo_layer_1_loss: 0.0238 - yolo_layer_2_loss: 1.1317 - yolo_layer_3_loss: 2.6662
#
# Epoch 00001: loss improved from inf to 3.82171, saving model to retina.h5
# Epoch 2/30
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
#  - 172s - loss: 3.9060 - yolo_layer_1_loss: 0.0418 - yolo_layer_2_loss: 1.1775 - yolo_layer_3_loss: 2.6867
#
# Epoch 00002: loss did not improve from 3.82171
# resizing:  320 320
# Epoch 3/30
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
#  - 166s - loss: 3.5823 - yolo_layer_1_loss: 0.0247 - yolo_layer_2_loss: 0.9434 - yolo_layer_3_loss: 2.6142
#
# Epoch 00003: loss improved from 3.82171 to 3.58235, saving model to retina.h5
# Epoch 4/30
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
#  - 168s - loss: 3.5491 - yolo_layer_1_loss: 0.0092 - yolo_layer_2_loss: 0.9367 - yolo_layer_3_loss: 2.6033
#
# Epoch 00004: loss improved from 3.58235 to 3.54915, saving model to retina.h5
# Epoch 5/30
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
#  - 170s - loss: 3.4748 - yolo_layer_1_loss: 0.0099 - yolo_layer_2_loss: 0.9173 - yolo_layer_3_loss: 2.5476
#
# Epoch 00005: loss improved from 3.54915 to 3.47480, saving model to retina.h5
# Epoch 6/30
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
#  - 171s - loss: 3.1926 - yolo_layer_1_loss: 0.0145 - yolo_layer_2_loss: 0.7183 - yolo_layer_3_loss: 2.4599
#
# Epoch 00006: loss improved from 3.47480 to 3.19258, saving model to retina.h5
# Epoch 7/30
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
#  - 170s - loss: 2.9967 - yolo_layer_1_loss: 0.0252 - yolo_layer_2_loss: 0.5685 - yolo_layer_3_loss: 2.4030
#
# Epoch 00007: loss improved from 3.19258 to 2.99674, saving model to retina.h5
# Epoch 8/30
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing: resizing:  384 384
#  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
#  - 168s - loss: 2.9077 - yolo_layer_1_loss: 0.0456 - yolo_layer_2_loss: 0.5072 - yolo_layer_3_loss: 2.3549
#
# Epoch 00008: loss improved from 2.99674 to 2.90766, saving model to retina.h5
# Epoch 9/30
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
#  - 172s - loss: 2.9436 - yolo_layer_1_loss: 0.0401 - yolo_layer_2_loss: 0.6138 - yolo_layer_3_loss: 2.2897
#
# Epoch 00009: loss did not improve from 2.90766
# Epoch 10/30
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
#  - 170s - loss: 2.7809 - yolo_layer_1_loss: 0.0230 - yolo_layer_2_loss: 0.5124 - yolo_layer_3_loss: 2.2456
#
# Epoch 00010: loss improved from 2.90766 to 2.78091, saving model to retina.h5
# Epoch 11/30
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
#  - 168s - loss: 2.9286 - yolo_layer_1_loss: 0.0239 - yolo_layer_2_loss: 0.5770 - yolo_layer_3_loss: 2.3278
#
# Epoch 00011: loss did not improve from 2.78091
# Epoch 12/30
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
#  - 174s - loss: 2.8369 - yolo_layer_1_loss: 0.0093 - yolo_layer_2_loss: 0.5239 - yolo_layer_3_loss: 2.3037
#
# Epoch 00012: loss did not improve from 2.78091
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 13/30
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
#  - 170s - loss: 2.4833 - yolo_layer_1_loss: 0.0244 - yolo_layer_2_loss: 0.4613 - yolo_layer_3_loss: 1.9975
#
# Epoch 00013: loss improved from 2.78091 to 2.48328, saving model to retina.h5
# Epoch 14/30
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
#  - 168s - loss: 2.2746 - yolo_layer_1_loss: 0.0139 - yolo_layer_2_loss: 0.3953 - yolo_layer_3_loss: 1.8653
#
# Epoch 00014: loss improved from 2.48328 to 2.27458, saving model to retina.h5
# Epoch 15/30
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
#  - 168s - loss: 2.1617 - yolo_layer_1_loss: 0.0184 - yolo_layer_2_loss: 0.3696 - yolo_layer_3_loss: 1.7736
#
# Epoch 00015: loss improved from 2.27458 to 2.16166, saving model to retina.h5
# Epoch 16/30
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
#  - 172s - loss: 2.1669 - yolo_layer_1_loss: 0.0290 - yolo_layer_2_loss: 0.3775 - yolo_layer_3_loss: 1.7604
#
# Epoch 00016: loss did not improve from 2.16166
# Epoch 17/30
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
#  - 170s - loss: 2.0795 - yolo_layer_1_loss: 0.0236 - yolo_layer_2_loss: 0.3424 - yolo_layer_3_loss: 1.7135
#
# Epoch 00017: loss improved from 2.16166 to 2.07951, saving model to retina.h5
# resizing:  352 352
# resizing:  320 320
# Epoch 18/30
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
#  - 169s - loss: 1.9397 - yolo_layer_1_loss: 0.0241 - yolo_layer_2_loss: 0.2839 - yolo_layer_3_loss: 1.6318
#
# Epoch 00018: loss improved from 2.07951 to 1.93975, saving model to retina.h5
# Epoch 19/30
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# ...
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
#  - 171s - loss: 2.0517 - yolo_layer_1_loss: 0.0180 - yolo_layer_2_loss: 0.3570 - yolo_layer_3_loss: 1.6767
#
# Epoch 00022: loss did not improve from 1.93975
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 23/30
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
#  - 166s - loss: 1.8476 - yolo_layer_1_loss: 0.0135 - yolo_layer_2_loss: 0.2382 - yolo_layer_3_loss: 1.5959
#
# Epoch 00023: loss improved from 1.93975 to 1.84764, saving model to retina.h5
# Epoch 24/30
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
#  - 168s - loss: 1.9090 - yolo_layer_1_loss: 0.0137 - yolo_layer_2_loss: 0.2765 - yolo_layer_3_loss: 1.6188
#
# Epoch 00024: loss did not improve from 1.84764
# Epoch 25/30
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
#  - 169s - loss: 1.9038 - yolo_layer_1_loss: 0.0090 - yolo_layer_2_loss: 0.3091 - yolo_layer_3_loss: 1.5857
#
# Epoch 00025: loss did not improve from 1.84764
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Epoch 26/30
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
#  - 170s - loss: 1.9176 - yolo_layer_1_loss: 0.0152 - yolo_layer_2_loss: 0.3259 - yolo_layer_3_loss: 1.5765
#
# Epoch 00026: loss did not improve from 1.84764
# Epoch 27/30
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
#  - 167s - loss: 1.9389 - yolo_layer_1_loss: 0.0371 - yolo_layer_2_loss: 0.2865 - yolo_layer_3_loss: 1.6153
#
# Epoch 00027: loss did not improve from 1.84764
# resizing:  448 448
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# Epoch 28/30
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
#  - 169s - loss: 2.0253 - yolo_layer_1_loss: 0.0326 - yolo_layer_2_loss: 0.3158 - yolo_layer_3_loss: 1.6768
#
# Epoch 00028: loss did not improve from 1.84764
# Epoch 00028: early stopping

# %%
import argparse
import os
import numpy as np
import json
from voc import parse_voc_annotation
from yolo import create_yolov3_model
from generator import BatchGenerator
from utils.utils import normalize, evaluate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from keras.models import load_model


config_path = './config.json'

with open(config_path) as config_buffer:    
    config = json.loads(config_buffer.read())

###############################
#   Create the validation generator
###############################  
valid_ints, labels = parse_voc_annotation(
    config['valid']['valid_annot_folder'], 
    config['valid']['valid_image_folder'], 
    config['valid']['cache_name'],
    config['model']['labels']
)

labels = labels.keys() if len(config['model']['labels']) == 0 else config['model']['labels']
labels = sorted(labels)

valid_generator = BatchGenerator(
    instances           = valid_ints, 
    anchors             = config['model']['anchors'],   
    labels              = labels,        
    downsample          = 32, # ratio between network input's size and network output's size, 32 for YOLOv3
    max_box_per_image   = 0,
    batch_size          = config['train']['batch_size'],
    min_net_size        = config['model']['min_input_size'],
    max_net_size        = config['model']['max_input_size'],   
    shuffle             = True, 
    jitter              = 0.0, 
    norm                = normalize
)

###############################
#   Load the model and do evaluation
###############################
os.environ['CUDA_VISIBLE_DEVICES'] = config['train']['gpus']

infer_model = load_model(config['train']['saved_weights_name'])

# compute mAP for all the classes
average_precisions = evaluate(infer_model, valid_generator)

# print the score
for label, average_precision in average_precisions.items():
    print(labels[label] + ': {:.4f}'.format(average_precision))
print('mAP: {:.4f}'.format(sum(average_precisions.values()) / len(average_precisions)))
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# CNV: 0.9020
# DME: 0.9540
# DRUSEN: 0.9279
# mAP: 0.9280
